# %% [markdown]
# # **Data Acquisition**

# %% [markdown]
# - In this section, we utilize openFDA's Food API to explore adverse events related to FDA-regulated foods, dietary supplements, and cosmetics.
# - Specifically, our focus is on the Soft Drink/Water industry.
# - Due to API constraints, the maximum value for the limit parameter is currently set at 1000.

# %%
# import urllib library
from urllib.request import urlopen
import pandas as pd

# import json
import json
# store the URL in url as
# parameter for urlopen
url = "https://api.fda.gov/food/event.json?search=products.industry_name:%22Soft+Drink/Water%22&limit=1000" # Currently, the largest allowed value for the limit parameter is 1000.

# store the response of URL
response = urlopen(url)

# storing the JSON response
# from url in data
data_json = json.loads(response.read())

# print the json response
print(data_json)
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service. Submission of an adverse event report does not constitute an admission that a product caused or contributed to an event. The information in these reports has not been scientifically or otherwise verified as to a cause and effect relationship and cannot be used to estimate incidence (occurrence rate) or to estimate risk.', 'terms': 'https://open.fda.gov/terms/', 'license': 'https://open.fda.gov/license/', 'last_updated': '2025-02-09', 'results': {'skip': 0, 'limit': 1000, 'total': 3476}}, 'results': [{'report_number': '2024-CFS-003668', 'outcomes': ['Other Outcome'], 'date_created': '20240410', 'reactions': ['Nausea', 'Rash', 'Throat irritation'], 'date_started': '20240404', 'consumer': {'age': '44', 'age_unit': 'year(s)', 'gender': 'Female'}, 'products': [{'role': 'SUSPECT', 'name_brand': 'GATORADE FROST THIRST QUENCHER', 'industry_code': '29', 'industry_name': 'Soft Drink/Water'}]}, {'report_number': '183113', 'outcomes': ['Other Outcome'], 'date_created': '20150218', 'reactions': ['MALAISE'], 'date_started': '20150110', 'consumer': {'gender': 'Male'}, 'products': [{'role': 'SUSPECT', 'name_brand': 'COCA-COLA CLASSIC', 'industry_code': '29', 'industry_name': 'Soft Drink/Water'}]}, {'report_number': '2017-CFS-000711', 'outcomes': ['Other Outcome'], 'date_created': '20170907', 'reactions': ['Abdominal pain', 'Diarrhoea'], 'date_started': None, 'consumer': {}, 'products': [{'role': 'SUSPECT', 'name_brand': 'black cherry soda', 'industry_code': '29', 'industry_name': 'Soft Drink/Water'}]}, {'report_number': '194654', 'outcomes': ['Other Outcome'], 'date_created': '20141009', 'reactions': ['ABNORMAL BEHAVIOUR', 'BURNING SENSATION', 'CARDIAC FIBRILLATION', 'HEART RATE INCREASED', 'HYPOAESTHESIA', 'PARAESTHESIA', 'STUPOR', 'THROAT IRRITATION'], 'date_started': '20141007', 'consumer': {'gender': 'Female'}, 'products': [{'role': 'SUSPECT', 'name_brand': 'KIRKLAND SIGNATURE DRINKING WATER, BOTTLED', 'industry_code': '29', 'industry_name': 'Soft Drink/Water'}]}, {'report_number': '69316', 'outcomes': ['Other Outcome'], 'date_created': '20040518', 'reactions': ['NAUSEA'], 'date_started': None, 'consumer': {'gender': 'Male'}, 'products': [{'role': 'SUSPECT', 'name_brand': 'PEPSI COLA BOTTLING MOUNTAIN DEW', 'industry_code': '29', 'industry_name': 'Soft Drink/Water'}]}, {'report_number': '177813', 'outcomes': ['Other Outcome'], 'date_created': '20140610', 'reactions': ['BURNING SENSATION', 'DIZZINESS', 'SKIN BURNING SENSATION', 'THROAT IRRITATION'], 'date_started': '20140608', 'consumer': {'gender': 'Female'}, 'products': [{'role': 'SUSPECT', 'name_brand': 'EXEMPTION 4', 'industry_code': '29', 'industry_name': 'Soft Drink/Water'}]}, {'report_number': '180017', 'outcomes': ['Other Outcome'], 'date_created': '20141002', 'reactions': ['DIZZINESS', 'MALAISE', 'NAUSEA'], 'date_started': '20140929', 'consumer': {'age': '56', 'age_unit': 'year(s)', 'gender': 'Female'}, 'products': [{'role': 'SUSPECT', 'name_brand': 'GATORADE G2  ORANGE DRINK', 'industry_code': '29', 'industry_name': 'Soft Drink/Water'}]}, {'report_number': '114618', 'outcomes': ['Visited Emergency Room'], 'date_created': '20090618', 'reactions': ['DIARRHOEA', 'HEADACHE', 'NAUSEA'], 'date_started': None, 'consumer': {'gender': 'Female'}, 'products': [{'role': 'SUSPECT', 'name_brand': 'KROGER PURIFIED DRINKING WATER', 'industry_code': '29', 'industry_name': 'Soft Drink/Water'}]}, {'report_number': '2021-CFS-003264', 'outcomes': ['Other Serious or Important Medical Event'], 'date_created': '20210411', 'reactions': ['Abdominal pain upper', 'Glossodynia', 'Headache', 'Toothache'], 'date_started': '20210411', 'consumer': {'age': '45', 'age_unit': 'year(s)', 'gender': 'Female'}, 'products': [{'role': ' ...

# %%
data_json.keys()
df = pd.DataFrame(data_json["results"])
df
# Out:
#        report_number                                           outcomes  \
# 0    2024-CFS-003668                                    [Other Outcome]
# 1             183113                                    [Other Outcome]
# 2    2017-CFS-000711                                    [Other Outcome]
# 3             194654                                    [Other Outcome]
# 4              69316                                    [Other Outcome]
# ..               ...                                                ...
# 995            67354                                    [Other Outcome]
# 996            66059                           [Visited Emergency Room]
# 997            65420    [Life Threatening, Hospitalization, Disability]
# 998            95035          [Hospitalization, Visited Emergency Room]
# 999           150950  [Disability, Other Serious or Important Medica...
#
#     date_created                                          reactions  \
# 0       20240410                  [Nausea, Rash, Throat irritation]
# 1       20150218                                          [MALAISE]
# 2       20170907                        [Abdominal pain, Diarrhoea]
# 3       20141009  [ABNORMAL BEHAVIOUR, BURNING SENSATION, CARDIA...
# 4       20040518                                           [NAUSEA]
# ..           ...                                                ...
# 995     20031209                                          [CHOKING]
# 996     20040123                   [TOOTH DISCOLOURATION, VOMITING]
# 997     20040106  [CHEST PAIN, DIZZINESS, EXTRASYSTOLES, HOSPITA...
# 998     20070801  [ATELECTASIS, CHEST PAIN, JOINT LOCK, JOINT ST...
# 999     20120406  [CONFUSIONAL STATE, DELIRIUM, DISORIENTATION, ...
#
#     date_started                                           consumer  \
# 0       20240404  {'age': '44', 'age_unit': 'year(s)', 'gender':...
# 1       20150110                                 {'gender': 'Male'}
# 2           None                                                 {}
# 3       20141007                               {'gender': 'Female'}
# 4           None                                 {'gender': 'Male'}
# ..           ...                                                ...
# 995     20031208  {'age': '62', 'age_unit': 'year(s)', 'gender':...
# 996         None                               {'gender': 'Female'}
# 997     20031101  {'age': '33', 'age_unit': 'year(s)', 'gender':...
# 998     20070731  {'age': '23', 'age_unit': 'year(s)', 'gender':...
# 999     20120324  {'age': '59', 'age_unit': 'year(s)', 'gender':...
#
#                                               products
# 0    [{'role': 'SUSPECT', 'name_brand': 'GATORADE F...
# 1    [{'role': 'SUSPECT', 'name_brand': 'COCA-COLA ...
# 2    [{'role': 'SUSPECT', 'name_brand': 'black cher...
# 3    [{'role': 'SUSPECT', 'name_brand': 'KIRKLAND S...
# 4    [{'role': 'SUSPECT', 'name_brand': 'PEPSI COLA...
# ..                                                 ...
# 995  [{'role': 'SUSPECT', 'name_brand': 'PEPSI COLA...
# 996  [{'role': 'SUSPECT', 'name_brand': 'STEWARTS R...
# 997  [{'role': 'SUSPECT', 'name_brand': 'COFFEE', '...
# 998  [{'role': 'SUSPECT', 'name_brand': 'ACE ENERGY...
# 999  [{'role': 'SUSPECT', 'name_brand': 'CRYSTAL GE...
#
# [1000 rows x 7 columns]

# %% [markdown]
# # **Data Cleaning and Handling Inconsistencies**

# %% [markdown]
# In this section, we will:
# - Fix incorrect data formats (e.g., convert date from string to datetime).
# - Correct the consumer and product columns, which contain data in nested dictionary format, by separating them into individual columns.
# - Handle lists in the outcomes and reactions columns by creating dummy variables for each item in the list for further analysis.
# - Remove missing values.
# - Remove duplicate rows.
# - Standardize all alphabets to lower case letters.
#
# Lastly, we will show the summary of the unique values for each category.

# %%
# Ensure Proper Datetime Formatting
df['date_created'] = pd.to_datetime(df['date_created'], format='%Y%m%d', errors='coerce')
df['date_started'] = pd.to_datetime(df['date_started'], format='%Y%m%d', errors='coerce')

# Normalize the 'consumer' column
consumer_df = pd.json_normalize(df['consumer'])
df = pd.concat([df.drop(columns=['consumer']), consumer_df], axis=1)

# Separate the 'role' and 'name_brand' from the 'products' column
df['product_role'] = df['products'].apply(lambda x: x[0]['role'] if isinstance(x, list) and len(x) > 0 else None)
df['product_name_brand'] = df['products'].apply(lambda x: x[0]['name_brand'].lower() if isinstance(x, list) and len(x) > 0 and isinstance(x[0].get('name_brand'), str) else None)

df.drop(columns=['products'], inplace=True)

# Drop report_number column, product_role and age_unit column since they are not necessary for further analysis
df.drop(columns=['report_number'], inplace=True)
df.drop(columns=['age_unit'], inplace=True)
df.drop(columns=['product_role'], inplace=True)

# Since data are in list format, flatten the data
df['outcomes'] = df['outcomes'].apply(lambda x: x if isinstance(x, list) else [x]) \
                             .explode() \
                             .apply(lambda x: x.lower() if isinstance(x, str) else x) \
                             .reset_index(drop=True)

df['reactions'] = df['reactions'].apply(lambda x: x if isinstance(x, list) else [x]) \
                                 .explode() \
                                 .apply(lambda x: x.lower() if isinstance(x, str) else x) \
                                 .reset_index(drop=True)

# Create dummy variables for the 'outcomes' column
outcomes_dummies = pd.get_dummies(df['outcomes'], prefix='outcome')

# Create dummy variables for the 'reactions' column
reactions_dummies = pd.get_dummies(df['reactions'], prefix='reaction')

df = pd.concat([df, outcomes_dummies, reactions_dummies], axis=1)

# Remove missing values (only  288 items are left)
df = df.dropna()

# Reset the index for dataframe
df = df.reset_index(drop=True)

df
# Out:
#                                      outcomes date_created  \
# 0                               other outcome   2024-04-10
# 1                               other outcome   2014-10-02
# 2    other serious or important medical event   2021-04-11
# 3                       required intervention   2016-07-19
# 4    other serious or important medical event   2011-11-01
# ..                                        ...          ...
# 283                    visited emergency room   2010-10-06
# 284            visited a health care provider   2003-12-09
# 285                             other outcome   2004-01-06
# 286  other serious or important medical event   2007-08-01
# 287                             other outcome   2012-04-06
#
#                   reactions date_started age  gender  \
# 0                    nausea   2024-04-04  44  Female
# 1        abnormal behaviour   2014-09-29  56  Female
# 2      cardiac fibrillation   2021-04-11  45  Female
# 3             hypoaesthesia   2016-07-16  33    Male
# 4    skin burning sensation   2011-03-14  70    Male
# ..                      ...          ...  ..     ...
# 283              chest pain   2010-08-07  67    Male
# 284            palpitations   2003-12-08  62  Female
# 285              hypoacusis   2003-11-01  33    Male
# 286                 pyrexia   2007-07-31  23    Male
# 287   visual acuity reduced   2012-03-24  59  Female
#
#                        product_name_brand  outcome_allergic reaction  \
# 0          gatorade frost thirst quencher                      False
# 1               gatorade g2  orange drink                      False
# 2         gatorade thirst quencher orange                      False
# 3                  puraqua purified water                      False
# 4    spring valley beta carotene 25000 iu                      False
# ..                                    ...                        ...
# 283                canada dry tonic water                      False
# 284                 pepsi cola soft drink                      False
# 285                                coffee                      False
# 286                      ace energy drink                      False
# 287  crystal geyser plastic bottled water                      False
#
#      outcome_death  outcome_disability  ...  reaction_viral test positive  \
# 0            False               False  ...                         False
# 1            False               False  ...                         False
# 2            False               False  ...                         False
# 3            False               False  ...                         False
# 4            False               False  ...                         False
# ..             ...                 ...  ...                           ...
# 283          False               False  ...                         False
# 284          False               False  ...                         False
# 285          False               False  ...                         False
# 286          False               False  ...                         False
# 287          False               False  ...                         False
#
#      reaction_vision blurred  reaction_visual acuity reduced  \
# 0                      False                           False
# 1                      False                           False
# 2                      False                           False
# 3                      False                           False
# 4                      False                           False
# ..                       ...                             ...
# 283                    False                           False
# 284                    False                           False
# 285                    False                           False
# 286                    False                           False
# 287                    False                            True
#
#      reaction_visual disturbance  reaction_visual impairment  \
# 0                          False                       False
# 1                          False                       False
# 2                          False                       False
# 3                          False                       False
# 4                          False                       False
# ..                           ...                         ...
# 283                        False                       False
# 284                        False                       False
# 285                        False                       False
# 286                        False                       False
# 287                        False                       False
#
#      reaction_vomiting  reaction_vulvovaginal burning sensation  \
# 0                False                                    False
# 1                False                                    False
# 2                False                                    False
# 3                False                                    False
# 4                False                                    False
# ..                 ...                                      ...
# 283              False                                    False
# 284              False                                    False
# 285              False                                    False
# 286              False                                    False
# 287              False                                    False
#
#      reaction_weight decreased  reaction_weight increased  reaction_wheezing
# 0                        False                      False              False
# 1                        False                      False              False
# 2                        False                      False              False
# 3                        False                      False              False
# 4                        False                      False              False
# ..                         ...                        ...                ...
# 283                      False                      False              False
# 284                      False                      False              False
# 285                      False                      False              False
# 286                      False                      False              False
# 287                      False                      False              False
#
# [288 rows x 265 columns]

# %%
initial_shape = df.shape
df = df.drop_duplicates()
print(f"Removed {initial_shape[0] - df.shape[0]} duplicate rows. New shape: {df.shape}")

print("Unique values after cleaning:")
print("Outcomes:", df['outcomes'].unique())
print("Reactions:", df['reactions'].unique())
print("Age:", df['age'].unique())
print("Gender:", df['gender'].unique())
print("Product Name Brand:", df['product_name_brand'].unique())
# Out:
# Removed 0 duplicate rows. New shape: (288, 265)
# Unique values after cleaning:
# Outcomes: ['other outcome' 'other serious or important medical event'
#  'required intervention' 'visited a health care provider'
#  'hospitalization' 'life threatening' 'visited emergency room'
#  'other serious outcome' 'disability' 'death']
# Reactions: ['nausea' 'abnormal behaviour' 'cardiac fibrillation' 'hypoaesthesia'
#  'skin burning sensation' 'diarrhoea' 'glossodynia' 'abdominal pain'
#  'hypotension' 'oropharyngeal swelling' 'eye pain' 'lymphadenopathy'
#  'musculoskeletal pain' 'asthenia' 'convulsion' 'pain' 'panic attack'
#  'vomiting' 'abdominal pain upper' 'oral discomfort' 'thermal burn'
#  'burning sensation' 'jaundice' 'photophobia' 'gastritis' 'dizziness'
#  'musculoskeletal disorder' 'abdominal discomfort' 'headache' 'fatigue'
#  'blister' 'dry skin' 'rash papular' 'infection' 'grand mal convulsion'
#  'gait disturbance' 'bronchitis' 'eye irritation' 'dyspnoea'
#  'weight decreased' 'urticaria' 'throat irritation' 'hyperhidrosis'
#  'atrial fibrillation' 'impaired work ability' 'malaise'
#  'product taste abnormal' 'feeling abnormal' 'self-induced vomiting'
#  'blood glucose increased' 'dehydration' 'urinary tract infection'
#  'physical examination' 'constipation' 'dysgeusia'
#  'body temperature fluctuation' 'generalised anxiety disorder'
#  'sleep disorder' 'pancreatitis' 'feeling of body temperature change'
#  'migraine' 'visual impairment' 'chest pain' 'dyspepsia' 'pruritus'
#  'retching' 'salivary hypersecretion' 'parosmia' 'stomach discomfort'
#  'choking' 'arthralgia' 'vision blurred' 'illness' 'skin irritation'
#  'escherichia infection' 'food poisoning' 'throat tightness'
#  'heart rate increased' 'muscle spasms' 'adverse event' 'erythema'
#  'myocardial infarction' 'nasal discomfort' 'emergency care examination'
#  'nasal congestion' 'body temperature increased' 'urogenital disorder'
#  'influenza like illness' 'hypersensitivity' 'paraesthesia oral' 'rash'
#  'adverse reaction' 'flatulence' 'gastrointestinal disorder' 'hangover'
#  'tremor' 'pharyngitis' 'gastrooesophageal reflux disease'
#  'cognitive disorder' 'disorientation' 'face oedema' 'lip ulceration'
#  'dysphagia' 'cerebrovascular accident' 'coordination abnormal'
#  'disturbance in attention' 'oesophagitis chemical' 'nasopharyngitis'
#  'dysphonia' 'haemoptysis' 'chromaturia' 'bacterial infection'
#  'viral test positive' 'stomatitis' 'oropharyngeal pain' 'ageusia'
#  'chemical injury' 'palpitations' 'hypoacusis' 'pyrexia'
#  'visual acuity reduced']
# Age: ['44' '56' '45' '33' '70' '13' '39' '25' '32' '24' '58' '4' '49' '16' '40'
#  '43' '67' '11' '54' '35' '15' '23' '14' '54.6' '2' '65' '27' '41' '32.77'
#  '28' '55' '36' '12' '37' '59' '57' '60' '74' '34' '51' '32.8' '20' '47'
#  '46.9' '8' '7' '71' '64' '38' '22' '3' '17' '48' '69' '29' '9' '42'
#  '24.6' '30' '19' '2.5' '31' '65.4' '10' '52' '18' '63' '50' '73' '24.67'
#  '46' '21' '68' '46.5' '89' '54.5' '72' '50.81' '6' '26' '51.2' '61'
#  '18.1' '44.58' '78' '38.3' '38.9' '63.5' '50.9' '76' '87' '61.69' '38.4'
#  '45.4' '49.37' '35.55' '53' '32.9' '43.6' '40.18' '80' '56.2' '62']
# Gender: ['Female' 'Male' 'Unknown']
# Product Name Brand: ['gatorade frost thirst quencher' 'gatorade g2  orange drink'
#  'gatorade thirst quencher orange' 'puraqua purified water'
#  'spring valley beta carotene 25000 iu'
#  'gatorade tangerine mandering g thirst quencher' 'red bull'
#  'kraft foods capri sun pacific cooler' 'real water alkaline water'
#  'gatorade' 'diet pepsi cola flavored, carbonated soft drink'
#  "hi-c flashin' fruit punch" 'kroger purified drinking water'
#  'kho bo vietnamese drinks' 'pure american spring water'
#  'kroger bottled water' 'san pellegrino mineral water' 'diet drinks'
#  'ice mountain spring water' 'capri sun fruit punch flavor juice'
#  'fiji artesanal water' 'refreshe spring water' 'pepsico products'
#  'minute maid fruit punch' 'members mark bottled water'
#  'quaker gatorade punch' 'gatorade glacier frost freeze' 'coke zero'
#  'fruity king  mini soda pineapple' 'pepsi cola soft drink'
#  'genesistoday plant-based probiotic dietary supplement' 'malta goya'
#  'protein20 infused protein water' 'diet cherry pepsi'
#  'abbott similac advance optigrow powdered infant formula'
#  'rite aide big fizz cola' 'powerade lemon lime powerade'
#  'pepsi bottled soda' 'clover valley dr topper'
#  'polar blast hawaiian punch' 'burn energy drink'
#  'amelia electrolyte water' 'sabra hummus small dipper'
#  'premium waters chippewa spring water 32 .5 liter bottles'
#  'bai flavored water oasis variety pack antioxident infused'
#  'nestle pure life purified water' 'diet rite'
#  'phd probiotic health daily, flavored water'
#  'capri sun juice drink blend fruit punch' 'mountain dew'
#  'food lion water purified' 'vita coco coconut water'
#  'simply light lemonade' 'diet coke' 'dr. pepper 7 up squirt soda'
#  'monster energy green' 'poland springs bottled water' 'dr. pepper'
#  'aquafina bottle water' 'harris teeter raspberry lime flavored seltzer'
#  "kirkland's signature tilapia, fresh frozen fillets"
#  "ryan's apple cider 100% juice" 'x mode energy drink' 'gatorades'
#  'gatorade propel' 'coca cola original'
#  'diamond falls pure granulated sugar' 'tang'
#  'absopure all natural spring water' 'ozarka  proudly texan'
#  'minute maid light lemonade' 'fred meyer purified drinking water'
#  'squirt soda' 'olipop classic root beer' 'gatorade lemon lime'
#  'simply lemonade with raspberry' 'niagara bottled water'
#  'san pellegrino sparkling mineral water' 'kraft kool-aid jammers cherry'
#  'hony boy canned pink salmon in water'
#  'earthbound farm organic 50/50 spinach and spring mix'
#  'hemp extract seltzer-8' 'naked protein banana chocolate juice smoothie'
#  'kozy shack original recipe rice pudding gluten free'
#  'runa clean energy drink unsweetened watermelon' 'rockstar energy drink'
#  'c4 energy' 'diet pepsi'
#  'enfamil nutramigen aa (prescription powdered formula)' 'mt. dew'
#  'pure life water' 'mug rootbeer'
#  'poland springs original sparkling water'
#  'kirkland powdered infant formula' 'mitra kratom seltzer'
#  'krazykritter vitamin drink apple gator'
#  'vita coco coconut water the original' 'poland spring spring water'
#  'monster energy ultra blue' 'poppi strawberry lemon prebiotic soda'
#  'diet mountain dew' 'red bull energy drink' 'distilled water'
#  'arizona sweetened tea' 'v8 vegetable juice'
#  'sobe life water, pomegranate cherry' 'vintage sheltzer lemon lime'
#  'dr. pepper squirt soda' 'goslings ginger beer'
#  'super ice pure & clean (kroger) ice cubes'
#  'glaceau xxx flavored vitamin water' 'kirkland water'
#  'nestle pure life water' 'nestle splash flavored water'
#  'cocain energy drink' "trader joe's natural mountain spring water"
#  'diet coca cola' 'stur liquid water enhancer' 'vita coco'
#  'schweppes ginger ale' 'pepsi cola soda' 'speed stack sports drink'
#  'vitamin water power c' 'care pharmaceuticals haydralyte'
#  'rehab tea+lemonade 15.5 oz' 'bubly sparkling water blackberry bubly'
#  "canfield's lemon natural flavor seltzer water"
#  'monster energy zero ultra' 'lifeline water' '7-up' 'sprite lemon lime'
#  'diet coke with caffeine'
#  'mountain dew code red (pepsico) carbonated soft drink'
#  'snapple apple juice drink' 'ice mountain bottled water'
#  'berry cool artificial fruit flavored soft drink'
#  'clovervalley purified drinking water'
#  'market pantry purified drinking water, enhanced with minerals for taste'
#  'sparkling ice' 'sprite' 'nursery purified water'
#  'archer farms market xl cooler, orange pineapple' 'fanta grape'
#  'full throttle' 'avitae water' 'coke diet-coke'
#  'diet drinks containing aspartame'
#  'fuze slenderize drink with citramax 200mg'
#  'coca cola spiced raspberry spiced coke' 'schweppes ginger ale, 10 oz.'
#  'amped hydrate juicy orange' 'cortislim'
#  'canada dry tonic water with quinine' 'real water'
#  'mistic sparkling lime kiwi water' 'klondike' 'rc cola, soft drink'
#  'sunny d' 'pepsi max diet pepsi' 'sobe lifewater' 'crystal geyser water'
#  'truestar supershot' 'coca cola coke' 'gatorade thirst quencher, orange'
#  'broccoli crowns' 'essentia purified bottled water' 'coke'
#  'motts active blastin berry hydrating juice beverage'
#  'poland bottled spring water' 'essentia 9.5ph'
#  'market pantry punch flavored 100% juice'
#  'gatorade fierce bold and intense thirst quencher blue cherry'
#  'sobe lean diet mango melon beverage' 'monster energy drink'
#  'pepsi regular pepsi' 'bonaqua flavored mineral water'
#  'acadia natural spring water' 'loca mocha java monster'
#  'planters pistachio lovers mix' 'ssips fruit punch' 'zephyr hills water'
#  'primo sparkletts water' 'orange powerade' 'roxanne bottled water'
#  'aquafina' 'sprite lemon lime soda' 'la croix coconut' 'ginger ale'
#  'power aide mountain berry blast' 'naked mango smoothie' 'fizz bizz soda'
#  'eternal naturally alkaline spring water'
#  'rainsberry farms rainberry fruit punch' 'rc cola'
#  'circle k blue  raspberry soda' 'puraqua' 'nusery purified water'
#  'full throttle energy drink' 'exemption 4' 'pepsi mango' 'pepsi'
#  'eternal bottled spring water' 'karma probiotic water'
#  "uncle ben's long grain & wild rice" 'sunny delight sunny delight'
#  'diet coke aspartame' 'poland springs spring water' 'coca cola'
#  'slammers trix' "le nature's ice water" 'coca-cola diet coke with lime'
#  'a&w root beer' 'bubly sparkling water coconut pineapple flavor'
#  'diet schweppes tonic water' 'propel fitness water' 'capri sun'
#  'deer park 100 % natural spring water' 'deer park water' 'fiji water'
#  'aspartame' 'controlled labs orange traid daily multivitamin'
#  'lifesavers' 'perrier mineral water' 'coca cola diet coke'
#  'dasani bottled water' "america's choice bottled spring water"
#  'monster energy' 'canada dry ginger ale naturally sweetened with stevia'
#  'sobe lifewater enlighten - blackberry grape'
#  'hinckley springs natural spring water' 'white rock ginger ale'
#  'poland spring water' 'mio sweet tea'
#  '365 everyday value organic unsweetened coconut original coconut milk beverage'
#  'nitro pepsi vanilla draft cola'
#  'nestle waters san pellegrino mineral water'
#  'belly washers spider man 100% juice fruit punch' 'diet pepsi cola'
#  'poland spring/100% natural spring water'
#  'fox ledge distilled water gallon'
#  'minute maid concentrated orange juice' 'bargs diet root beer'
#  'white rock sioux city cream soda' 'dasani water'
#  'jewell infant drinking water' 'aloe vera fresh' 'vua kho bo xi muoi'
#  'honest tea peach oyo-la-long tea' 'arrowhead water' 'wild cherry pepsi'
#  'zephyrhills florida spring water' 'act ii kettle corn'
#  'feisty cherry diet coke'
#  'thurst burst orange artificially flavored non-carbonated drink'
#  'canada dry tonic water' 'coffee' 'ace energy drink'
#  'crystal geyser plastic bottled water']
